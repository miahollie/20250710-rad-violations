# %% [markdown]
# ## Leftover code from this project that i'd like to reference again

# %%
 # for line in lines: # <-- loop through each line (which are now single rows of text found on each page)
        #     if line.startswith('BBL'): # <-- if the line starts with BBL 
        #         header = line.split() # <-- split it into parts, forming a list

        #     elif re.match(r'^\d{10}',line): # <-- otherwise find the lines that start with a 10-digit string
        #         data = line.split() # <-- split it into parts
                
        #         ## assign the bbl number
        #         bbl = data[0] # <-- the first list item is the BBL number

# %%
       #         ## assign the building number
        #         if len(data) > 2 and re.match(r'^\d{1,2}$',data[1]) and not re.match(r'SOUTH',data[2]):# <-- if the second list item is 1 or 2 digits long
        #             bldg_num = data[1] # <-- but if it is 1-2 digits long, then assign that as the building number
        #         else:
        #             data.insert(1, None) # <-- otherwise insert a new list item, and insert "None" as the data 
                
        #         ## assign the data from the 'M' column
        #         if len(data) > 2 and not re.match(r'M', data[2]): # <-- if data has more than 2 list items + the third list item doesn't start w/ M
        #             data.insert(2, None) # <-- then insert a new third list item, with no data
        #         em = data[2] if len(data) > 2 else None  # <-- otherwise assign third list item to a variable

        #         ## assign the house number
        #         if len(data) > 3: # <-- if data has more than three list items
        #             house_num = data[3] # <-- the third (really the fourth)list item is the house number

        #         ## assign the cardinal direction included in the address, if there is one
        #         if len(data) > 4 and not re.match(r'^(NORTH|SOUTH|EAST$|WEST)', data[4]):
        #             data.insert(4, None) # <-- if there's no direction, than insert 'None' in the fourt index place
        #         direction = data[4] if len(data) > 4 else None # <-- if there is, then assign it

        #         ## making an exception for east new york
        #         if len(data) > 5 and re.match(r'^EAST$', str(data[4])) and re.match(r'^NEW', data[5]):
        #             data[5] = 'NEW YORK'
        #             data.pop(6) if len(data) > 6 else None
        #         else:
        #             data.append(None)
                
        #         ## assigning street names... with a lot of caveats for street names with more than one word
        #         if len(data) > 5 and re.match(r'^(A$|C$)',data[5]):
        #             data[5] = 'ADAM C POWELL'
        #             if len(data) > 6:
        #                 data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^MALCOLM', data[5]):
        #             data[5] = 'MALCOLM X'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^FORT', data[5]):
        #             data[5] = 'FORT WASHINGTON'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^CROTONA', data[5]):
        #             data[5] = 'CROTONA PARK'

# %%
      #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^None', str(data[4])) and re.match(r'^229TH', str(data[5])):
        #             data[5] = '229TH DRIVE'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^REEDS', data[5]):
        #             data[5] = 'REEDS MILL'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^OLD', data[5]):
        #             data[5] = 'OLD BROADWAY'
        #             data.pop(6)  # Remove the word after
        #         elif len(data) > 6 and re.match(r'^BEACH', data[5]) and re.match(r'^CHANNEL',data[6]):
        #             data[5] = 'BEACH CHANNEL'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 6 and re.match(r'^BEACH', data[5]) and re.match(r'^\d{1,2}',data[6]):
        #             data[5] = f'BEACH {data[6]}'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^FREDERICK', data[5]):
        #             data[5] = 'FREDERICK DOUGLASS'
        #             data.pop(6)
        #         elif len(data) > 5 and re.match(r'^REV', data[5]):
        #             data[5] = 'REV JAMES POLITE'
        #             data.pop(6)
        #         elif len(data) > 5 and re.match(r'^VAN', data[5]):
        #             data[5] = 'VAN SICLEN'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'^TEN', data[5]):
        #             data[5] = 'TEN EYCK'
        #             data.pop(6)  # Remove the word after 
        #         elif len(data) > 5 and re.match(r'1/2', data[5]):
        #             data[5] = data[6] if len(data) > 6 else None
        #             data.pop(6)
        #         elif len(data) > 5 and re.match(r'^SAINT', data[5]):
        #             data[5] = f'SAINT {data[6]}'
        #             data.pop(6)
        #         elif len(data) > 5:
        #             pass
 
        #         else:
        #             data.append(None)
                
        #         ## once we finish changing the outlier street names, assign all street names a variable
        #         street_name = data[5] if len(data) > 5 else None

# %%
      #         ## assign street types (street, blvd, road, etc) to a variable
        #         if len(data) > 7 and re.match(r'ADAM C POWELL',data[5]): # <-- if list is longer than 6 and is AC POWELL
        #             street_type = data[7]
        #         elif len(data) > 9 and re.match(r'REV JAMES POLITE', data[5]):
        #             street_type = data[8]
        #         elif len(data) > 6 and re.match(r'^[A-Z]', data[6]):
        #             street_type = data[6]
        #         else:
        #             data.append(None)
        #         ## assign zip code
        #         if len(data) > 7 and re.match(r'^\d{5}', data[7]):
        #             zip_code = data[7]
        #         else:
        #             data.append(None)
                
        #         if len(data) > 13 and data[13] is not None and re.match(r'^\d{7}',str(data[13])):
        #             bin_num = data[13]
        #         else:
        #             data.append(None)
                
        #         rows = {
        #             'BBL':bbl,
        #             'BIN':bin_num,
        #             'BLDG#':bldg_num,
        #             'M':em,
        #             'direction':direction,
        #             'house_num':house_num,
        #             'street_name':street_name,
        #             'street_type':street_type,
        #             'zip':zip_code
        #         }

        #         developments.append(rows)

# %%
 #     development = lines[1] if not re.match(r'^\d{10}', lines[1]) else None

        # print(development)
        
        # # Find all development names on this page
        # development_name = [] # <-- empty list for storing 
        # for i, line in enumerate(lines): # <-- loop throught the lines of text we just created
        #     line = line.strip() # <-- strip of any whitespace
            
        #     if line.startswith('Borough:'): # <-- if the line starts with boro...
        #         building_name = '' 
        #         for j in range(i-1, -1, -1):
        #             prev_line = lines[j].strip()
        #             if prev_line and 'PACT DEVELOPMENTS' not in prev_line and 'DIRECTORY' not in prev_line:
        #                 building_name = prev_line
        #                 break
                    
            #         # Extract all info from this line and surrounding lines
            #         section_text = ' '.join(lines[i:min(i+3, len(lines))])
                    
            #         borough_match = re.search(r'Borough:\s*([A-Z]+)', section_text)
            #         total_units_match = re.search(r'TOTAL UNITS:\s*(\d+)', section_text)
            #         tds_match = re.search(r'TDS #\s*(\d+)', section_text)
            #         date_match = re.search(r'TRANSFERRED DATE:\s*([\d/]+)', section_text)
                    
            #         sections.append({
            #             'building_name': building_name,
            #             'borough': borough_match.group(1) if borough_match else '',
            #             'total_units': total_units_match.group(1) if total_units_match else '',
            #             'tds': tds_match.group(1) if tds_match else '',
            #             'transferred_date': date_match.group(1) if date_match else ''
            #         })
            
            # # Extract all tables from the page
            # tables = page.extract_tables()
            
            # # Process each table with its corresponding section
            # section_idx = 0
            # for table in tables:
            #     if not table or len(table) < 2:
            #         continue
                
            #     # Get the section for this table
            #     if section_idx < len(sections):
            #         section = sections[section_idx]
            #     else:
            #         # Fallback to last section if we run out
            #         section = sections[-1] if sections else {}
                
    #             # First row is headers
    #             headers = [h.strip() if h else '' for h in table[0]]
                
    #             # Process each data row
    #             for row in table[1:]:
    #                 # Skip empty rows
    #                 if not any(row):
    #                     continue
                    
    #                 row_dict = {
    #                     'building_name': section.get('building_name', ''),
    #                     'borough': section.get('borough', ''),
    #                     'total_units': section.get('total_units', ''),
    #                     'tds': section.get('tds', ''),
    #                     'transferred_date': section.get('transferred_date', ''),
    #                     'page_number': page_num
    #                 }
                    
    #                 # Add table columns
    #                 for header, value in zip(headers, row):
    #                     if header:  # Only add if header exists
    #                         clean_header = header.lower().replace(' ', '_').replace('#', '').replace('_', '', 1) if header.startswith('#') else header.lower().replace(' ', '_').replace('#', '')
    #                         row_dict[clean_header] = value if value else ''
                    
    #                 all_data.append(row_dict)
                
    #             # Move to next section after processing a table
    #             section_idx += 1
    
    # # Create DataFrame
    # df = pd.DataFrame(all_data)
    # return df

# %%
        # else:
        #     data = table

        #     if 'headers' in locals():
        #         df = pd.DataFrame(columns=headers, data=data)
        #         developments.append(df)
        
        # # if not table or len(table) < 2: # <-- if it's not an actual table or if the table has fewer than two items
        # #     skipped.append(table) # <-- append to a list
        # #     continue

        # # elif re.match(r'^BBL',table[0][0]):
        # #     header = table[0]
        
        # # else:
        # #     data.append(None)

        # # data = table[1:]

        # # df = pd.DataFrame(columns=header, data=data)
        # # developments.append(df)
